# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, r2_score

# %%
add_data = pd.read_csv("reklama_sales.csv")

add_df = pd.DataFrame(add_data)

add_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
tv = add_df[['TV']]
radio = add_df[['Radio']]
newspaper = add_df[['Newspaper']]
sales = add_df['Sales']
plt.scatter(tv, sales, color="blue")
plt.scatter(radio, sales, color="red")
plt.scatter(newspaper, sales, color="green")

plt.title("Commercial Prises")
plt.xlabel("Products")
plt.ylabel("Sales")
plt.show()

# %%
tv_x_train, tv_x_test, tv_y_train, tv_y_test = train_test_split(tv, sales, test_size=0.2, random_state=42)

tv_x_train, tv_x_test
# Out:
# (        TV
#  79   116.0
#  197  177.0
#  38    43.1
#  24    62.3
#  122  224.0
#  ..     ...
#  106   25.0
#  14   204.1
#  92   217.7
#  179  165.6
#  102  280.2
#
#  [160 rows x 1 columns],
#          TV
#  95   163.3
#  15   195.4
#  30   292.9
#  158   11.7
#  128  220.3
#  115   75.1
#  69   216.8
#  170   50.0
#  174  222.4
#  45   175.1
#  66    31.5
#  182   56.2
#  165  234.5
#  78     5.4
#  186  139.5
#  177  170.2
#  56     7.3
#  152  197.6
#  82    75.3
#  68   237.4
#  124  229.5
#  16    67.8
#  148   38.0
#  93   250.9
#  65    69.0
#  60    53.5
#  84   213.5
#  67   139.3
#  125   87.2
#  132    8.4
#  9    199.8
#  18    69.2
#  55   198.9
#  75    16.9
#  150  280.7
#  104  238.2
#  135   48.3
#  137  273.7
#  164  117.2
#  76    27.5)

# %%
radio_x_train, radio_x_test, radio_y_train, radio_y_test= train_test_split(radio, sales, test_size=0.2, random_state=42)

radio_x_train, radio_x_test
# Out:
# (     Radio
#  79     7.7
#  197    9.3
#  38    26.7
#  24    12.6
#  122    2.4
#  ..     ...
#  106   11.0
#  14    32.9
#  92    33.5
#  179   10.0
#  102   10.1
#
#  [160 rows x 1 columns],
#       Radio
#  95    31.6
#  15    47.7
#  30    28.3
#  158   36.9
#  128   49.0
#  115   35.0
#  69    43.9
#  170   11.6
#  174    3.4
#  45    22.5
#  66    24.6
#  182    5.7
#  165    3.4
#  78    29.9
#  186    2.1
#  177    7.8
#  56    28.1
#  152   23.3
#  82    20.3
#  68    27.5
#  124   32.3
#  16    36.6
#  148   40.3
#  93    36.5
#  65     9.3
#  60     2.0
#  84    43.0
#  67    14.5
#  125   11.8
#  132   27.2
#  9      2.6
#  18    20.5
#  55    49.4
#  75    43.7
#  150   13.9
#  104   34.3
#  135   47.0
#  137   28.9
#  164   14.7
#  76     1.6)

# %%
bilb_x_train, bilb_x_test, bilb_y_train, bilb_y_test= train_test_split(newspaper, sales, test_size=0.2, random_state=42)

bilb_x_train,bilb_x_test
# Out:
# (     Newspaper
#  79        23.1
#  197        6.4
#  38        35.1
#  24        18.3
#  122       15.6
#  ..         ...
#  106       29.7
#  14        46.0
#  92        59.0
#  179       17.6
#  102       21.4
#
#  [160 rows x 1 columns],
#       Newspaper
#  95        52.9
#  15        52.9
#  30        43.2
#  158       45.2
#  128        3.2
#  115       52.7
#  69        27.2
#  170       18.4
#  174       13.1
#  45        31.5
#  66         2.2
#  182       29.7
#  165       84.8
#  78         9.4
#  186       26.6
#  177       35.2
#  56        41.4
#  152       14.2
#  82        32.5
#  68        11.0
#  124       74.2
#  16       114.0
#  148       11.9
#  93        72.3
#  65         0.9
#  60        21.4
#  84        33.8
#  67        10.2
#  125       25.9
#  132        2.1
#  9         21.2
#  18        18.3
#  55        60.0
#  75        89.4
#  150       37.0
#  104        5.3
#  135        8.5
#  137       59.7
#  164        5.4
#  76        20.7)

# %%
bek_tv = LinearRegression()
bek_rad = LinearRegression()
bek_bilb = LinearRegression()

bek_tv.fit(tv_x_train,tv_y_train)
bek_rad.fit(radio_x_train, radio_y_train)
bek_bilb.fit(bilb_x_train, bilb_y_train)
# Out:
# LinearRegression()

# %%
print("intercept:tv:", bek_tv.intercept_)
print("Slope:tv:", bek_tv.coef_[0])
print("intercept:rad:", bek_rad.intercept_)
print("Slope:tv:", bek_rad.coef_[0])
print("intercept:bilb:", bek_bilb.intercept_)
print("Slope:tv:", bek_bilb.coef_[0])
# Out:
# intercept:tv: 7.00710842824185
# Slope:tv: 0.055482943931463184
# intercept:rad: 12.585523978355143
# Slope:tv: 0.12000113752716518
# intercept:bilb: 14.2174147917439
# Slope:tv: 0.03717438551561708

# %%
tv_y_pred = bek_tv.predict(tv_x_test)

result_tv = pd.DataFrame({"actual":tv_y_test, "Predict": tv_y_pred})
result_tv
# Out:
#      actual    Predict
# 95     16.9  16.067473
# 15     22.4  17.848476
# 30     21.4  23.258063
# 158     7.3   7.656259
# 128    24.7  19.230001
# 115    12.6  11.173878
# 69     22.3  19.035811
# 170     8.4   9.781256
# 174    16.5  19.346515
# 45     16.1  16.722172
# 66     11.0   8.754821
# 182     8.7  10.125250
# 165    16.9  20.017859
# 78      5.3   7.306716
# 186    10.3  14.746979
# 177    16.7  16.450305
# 56      5.5   7.412134
# 152    16.6  17.970538
# 82     11.3  11.184974
# 68     18.9  20.178759
# 124    19.7  19.740444
# 16     12.5  10.768852
# 148    10.9   9.115460
# 93     22.2  20.927779
# 65     11.3  10.835432
# 60      8.1   9.975446
# 84     21.7  18.852717
# 67     13.4  14.735883
# 125    10.6  11.845221
# 132     5.7   7.473165
# 9      15.6  18.092601
# 18     11.3  10.846528
# 55     23.7  18.042666
# 75      8.7   7.944770
# 150    16.1  22.581171
# 104    20.7  20.223146
# 135    11.6   9.686935
# 137    20.8  22.192790
# 164    11.9  13.509709
# ...

# %%
rad_y_pred = bek_rad.predict(radio_x_test)

result_rad = pd.DataFrame({"actual":radio_y_test, "Predict": rad_y_pred})
result_rad
# Out:
#      actual    Predict
# 95     16.9  16.377560
# 15     22.4  18.309578
# 30     21.4  15.981556
# 158     7.3  17.013566
# 128    24.7  18.465580
# 115    12.6  16.785564
# 69     22.3  17.853574
# 170     8.4  13.977537
# 174    16.5  12.993528
# 45     16.1  15.285550
# 66     11.0  15.537552
# 182     8.7  13.269530
# 165    16.9  12.993528
# 78      5.3  16.173558
# 186    10.3  12.837526
# 177    16.7  13.521533
# 56      5.5  15.957556
# 152    16.6  15.381550
# 82     11.3  15.021547
# 68     18.9  15.885555
# 124    19.7  16.461561
# 16     12.5  16.977566
# 148    10.9  17.421570
# 93     22.2  16.965565
# 65     11.3  13.701535
# 60      8.1  12.825526
# 84     21.7  17.745573
# 67     13.4  14.325540
# 125    10.6  14.001537
# 132     5.7  15.849555
# 9      15.6  12.897527
# 18     11.3  15.045547
# 55     23.7  18.513580
# 75      8.7  17.829574
# 150    16.1  14.253540
# 104    20.7  16.701563
# 135    11.6  18.225577
# 137    20.8  16.053557
# 164    11.9  14.349541
# ...

# %%
bilb_y_pred = bek_bilb.predict(bilb_x_test)

result_bilb = pd.DataFrame({"actual":bilb_y_test, "Predict": bilb_y_pred})
result_bilb
# Out:
#      actual    Predict
# 95     16.9  16.183940
# 15     22.4  16.183940
# 30     21.4  15.823348
# 158     7.3  15.897697
# 128    24.7  14.336373
# 115    12.6  16.176505
# 69     22.3  15.228558
# 170     8.4  14.901423
# 174    16.5  14.704399
# 45     16.1  15.388408
# 66     11.0  14.299198
# 182     8.7  15.321494
# 165    16.9  17.369803
# 78      5.3  14.566854
# 186    10.3  15.206253
# 177    16.7  15.525953
# 56      5.5  15.756434
# 152    16.6  14.745291
# 82     11.3  15.425582
# 68     18.9  14.626333
# 124    19.7  16.975754
# 16     12.5  18.455295
# 148    10.9  14.659790
# 93     22.2  16.905123
# 65     11.3  14.250872
# 60      8.1  15.012947
# 84     21.7  15.473909
# 67     13.4  14.596594
# 125    10.6  15.180231
# 132     5.7  14.295481
# 9      15.6  15.005512
# 18     11.3  14.897706
# 55     23.7  16.447878
# 75      8.7  17.540805
# 150    16.1  15.592867
# 104    20.7  14.414439
# 135    11.6  14.533397
# 137    20.8  16.436726
# 164    11.9  14.418156
# ...

# %%
mse_TV = mean_squared_error(tv_y_test, tv_y_pred)
r2_TV = r2_score(tv_y_test, tv_y_pred)
mse_RAD = mean_squared_error(radio_y_test, rad_y_pred)
r2_RAD = r2_score(radio_y_test, rad_y_pred)
mse_BILB = mean_squared_error(bilb_y_test, bilb_y_pred)
r2_BILB = r2_score(bilb_y_test, bilb_y_pred)

# %%
print("Mean Squared Error:TV:", mse_TV)
print("R^2 Score:TV:", r2_TV)
print("Mean Squared Error:RADIO:", mse_RAD)
print("R^2 Score:RADIO:", r2_RAD)
print("Mean Squared Error:BILB:", mse_BILB)
print("R^2 Score:BILB:", r2_BILB)
# Out:
# Mean Squared Error:TV: 6.101072906773963
# R^2 Score:TV: 0.802561303423698
# Mean Squared Error:RADIO: 27.595581948583174
# R^2 Score:RADIO: 0.10697088619553419
# Mean Squared Error:BILB: 30.759376922769615
# R^2 Score:BILB: 0.004586344085821592

# %%
plt.scatter(tv_x_train, tv_y_train, color="blue", label="Taining Data TV")
plt.scatter(tv_x_test, tv_y_test, color="green", label="Tesing data TV")
plt.plot(tv, bek_tv.predict(tv), color="red", label="Regression Line TV")


plt.title("TV, RADIO AND COMMERCIALS LINEAR REGRESSION")
plt.xlabel("tv, radio, com")
plt.ylabel("sales")
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(radio_x_train, radio_y_train, color="yellow", label="Taining Data RADIO")
plt.scatter(radio_x_test, radio_y_test, color="gray", label="Tesing data RADIO")
plt.plot(radio, bek_rad.predict(radio), color="blue", label="Regression Line RADIO",linewidth = '5')
plt.title("TV, RADIO AND COMMERCIALS LINEAR REGRESSION")
plt.xlabel("tv, radio, com")
plt.ylabel("sales")
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(bilb_x_train, bilb_y_train, color="red", label="Taining Data BILBOADRD")
plt.scatter(bilb_x_test, bilb_y_test, color="black", label="Tesing data BILBOARD")
plt.plot(newspaper, bek_bilb.predict(newspaper), color="Orange", label="Regression Line BILBOARD")
plt.title("TV, RADIO AND COMMERCIALS LINEAR REGRESSION")
plt.xlabel("tv, radio, com")
plt.ylabel("sales")
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
